# %% [markdown]
# # Policy comparison
# All branches start from one immutable warm-up state. The notebook only selects a study configuration and displays package output.

# %%
from pathlib import Path
from IPython.display import Image, display
from urbancrime.studies import compare_policies

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
CONFIG = ROOT / 'configs/smoke/policy_comparison.yaml'
results = compare_policies(CONFIG)

# %%
display(Image(filename=ROOT / 'runs/smoke-policy-comparison/policy_comparison.png'))
